# %%
from ultralytics import YOLO

# Load baseline YOLOv8n
model = YOLO('yolov8n.pt')

# Train baseline with cache explicitly disabled to avoid missing file errors
results = model.train(
    data='../dataset.yaml',
    epochs=110,
    imgsz=640,
    batch=16,
    seed=42,
    patience=35,
    cache=False,  # <--- Disables reading/writing bad cache files
    name='underwater_refined_yolov8n'
)

print("Baseline training complete! Weights saved to: runs/detect/underwater_refined_yolov8n/weights/best.pt")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#       2
#       3 # Load baseline YOLOv8n
#       4 model = YOLO('yolov8n.pt')
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\SUCHISMITA\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\__init__.py:38, in __getattr__(name)
#      36 """Lazy-import model classes on first access."""
#      37 if name in MODELS:
# ---> 38     return getattr(importlib.import_module("ultralytics.models"), name)
#      39 raise AttributeError(f"module {__name__} has no attribute {name}")
#
# File c:\Users\SUCHISMITA\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ...
